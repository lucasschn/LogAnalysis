# %%
import sys
sys.path.append('/home/lucas/Documents/Log_Analysis')
import analog
import matplotlib.pyplot as plt
import numpy as np

# %%
folder = '/home/lucas/Documents/Log_Analysis/Logs/Snow Orange avoidance testing'
log_file = analog.pathfromQGC(folder,index='221')
print(log_file)
info = analog.logextract(log_file,['vehicle_local_position','distance_sensor','sensor_combined'])
print(info.keys())
# Out:
# /home/lucas/Documents/Log_Analysis/Logs/Snow Orange avoidance testing/log_221_2019-10-3-12-34-52(crashed_against_wood_stack).ulg
# dict_keys(['time_ds', 'dist', 'time_vlp', 'x', 'y', 'z', 'vx', 'vy', 'vz', 'time_sc', 'acc_x', 'acc_y', 'acc_z', 'roll', 'pitch', 'yaw', 'freq', 'Ax', 'Ay', 'Az', 'R', 'P', 'Y'])

# %%
time=info['time_ds']
dist=info['dist']
time_sc = info['time_sc']
acc_x = info['acc_x']
acc_y = info['acc_y']
acc_z = info['acc_z']
pitch = info['pitch']

# %%
# %matplotlib notebook

plt.figure()
#plt.subplot(211)
plt.plot(time,dist)
plt.ylabel('distance sensor (m)')
#plt.grid()
#plt.subplot(212)
plt.plot(time_sc[time_sc > time[0]], pitch[time_sc > time[0]])
plt.grid()
plt.xlabel('time (s)')
plt.ylabel('pitch rate (rad/s)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'pitch rate (rad/s)')
